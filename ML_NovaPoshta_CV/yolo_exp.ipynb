# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator
from matplotlib import pyplot as plt
import cv2
import os

# %%
img_location = "./data/images_data/1010(2023-05-29T12_17_09).jpg"

# %%
model = YOLO('./models/yolov8n-oiv7.pt')

# %%
results = model.predict(source=img_location,conf=0.05)
# Out:
# image 1/1 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1010(2023-05-29T12_17_09).jpg: 640x320 1 Box, 224.7ms
# Speed: 8.2ms preprocess, 224.7ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 320)

# %%
results = model.predict(source=,conf=0.15,)
# Out:
# image 1/120 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1001(2023-06-07T08_06_44).jpg: 640x480 1 Box, 266.3ms
# image 2/120 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1002(2023-06-29T11_47_18).jpg: 384x640 (no detections), 172.2ms
# image 3/120 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1010(2023-05-29T12_17_09).jpg: 640x320 (no detections), 189.0ms
# image 4/120 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1012(2023-07-04T08_32_24).jpg: 384x640 (no detections), 125.6ms
# image 5/120 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1013(2023-07-04T08_27_05).jpg: 384x640 1 Whiteboard, 122.5ms
# ...

# %%
fold_location = os.listdir("./data/images_data/")
i=0
for location in fold_location:
    i+=1
    if i==10:
        break
    img_location="./data/images_data/"+location
    image = cv2.imread(img_location)
    results = model.predict(source=img_location,conf=0.05)

    for r in results:
        annotator = Annotator(image)
        boxes = r.boxes
        for box in boxes:
            b = box.xyxy[0]  # get box coordinates in (left, top, right, bottom) format
            c = box.cls
            annotator.box_label(b, model.names[int(c)])

    img = annotator.result()  
    image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(image_rgb)
    plt.show()
# Out:
# image 1/1 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1001(2023-06-07T08_06_44).jpg: 640x480 1 Box, 284.5ms
# Speed: 4.0ms preprocess, 284.5ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1002(2023-06-29T11_47_18).jpg: 384x640 1 Whiteboard, 152.9ms
# Speed: 4.0ms preprocess, 152.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1010(2023-05-29T12_17_09).jpg: 640x320 1 Box, 1 Kitchen appliance, 155.2ms
# Speed: 3.0ms preprocess, 155.2ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 320)
# ...

# %%
from ultralytics import YOLO
# Load a model
model = YOLO("./models/yolov8n.pt")  # build a new model from scratch
# Use the model
model.train(data="config.yaml", epochs=15)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.231 🚀 Python-3.11.4 torch-2.0.1+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# ...

# %%
model = YOLO('./runs/detect/train/weights/best.pt')

# %%
results = model(img_location)
# Out:
# image 1/1 c:\Users\Tymof\OneDrive\Desktop\education\Practice\Meduzzen_Intership\ML_NovaPoshta_CV\data\images_data\1002(2023-06-29T11_47_18).jpg: 384x640 (no detections), 102.2ms
# Speed: 2.0ms preprocess, 102.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
for r in results:
    boxes = r.boxes
    print(boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (607, 1080)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
